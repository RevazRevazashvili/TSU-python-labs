# %% [markdown]
# <a href="https://colab.research.google.com/github/RevazRevazashvili/TSU-python-labs/blob/main/Lab_11_MatPlotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # matplotlib შესავალი

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## ძირითადი

# %%
lst_x = [1, 2, 4]
lst_y = [3, 6, 9]

# %%
# plot x
plt.plot(lst_x)

# %%
#  plot x, y
plt.plot(lst_x, lst_y)

# %% [markdown]
# ### .show()

# %%
# add show()
plt.plot(lst_x, lst_y)
plt.show()

# %%
plt.plot(lst_x, lst_y)
plt.plot(lst_x)

# %%
plt.plot(lst_x, lst_y)
plt.show()

plt.plot(lst_x)
plt.show()

# %%
plt.show()

# %% [markdown]
# ### .title()

# %%
# add title()
plt.plot(lst_x, lst_y)
plt.title('Y = 3 * X')
plt.show()

# %% [markdown]
# ### ღერძების დასახელებები

# %% [markdown]
# #### X

# %%
# x ღერძის სახელი
plt.plot(lst_x, lst_y)
plt.title('Y = 3 * X')
plt.xlabel('X Axis')
plt.show()

# %% [markdown]
# #### Y

# %%
# y ღერძის სახელი
plt.plot(lst_x, lst_y)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Y = 3 * X')
plt.show()

# %% [markdown]
# ### Ticks

# %%
# X ticks-ის დამატება
plt.plot(lst_x, lst_y)

plt.title('Y = 3 * X')

plt.xlabel('X Axis')
plt.ylabel('Y')

plt.xticks(lst_x)

plt.show()

# %%
# Y ticks-ის დამატება
plt.plot(lst_x, lst_y)

plt.title('Y = 3 * X')

plt.xlabel('X Axis')
plt.ylabel('Y')

plt.yticks(lst_y)

plt.show()

# %%
# X ticks-ის დამატება
plt.plot(lst_x, lst_y)

plt.title('Y = 3 * X')

plt.xlabel('X Axis')
plt.ylabel('Y')

plt.xticks(lst_x)
plt.yticks(lst_y)

plt.show()

# %%
# X ticks-ის დამატება
plt.plot(lst_x, lst_y)

plt.title('Y = 3 * X')

plt.xlabel('X Axis')
plt.ylabel('Y')

plt.xticks(lst_x + [1.7])

plt.show()

# %%
x_max = max(lst_x)
x_min = min(lst_x)
list(range(x_min-1, x_max + 2))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
# y ticks-ის დამატება
# X ticks-ის დამატება
plt.plot(lst_x, lst_y)

plt.title('Y = 3 * X')

plt.xlabel('X Axis')
plt.ylabel('Y')

x_max = max(lst_x)
x_min = min(lst_x)

plt.xticks(range(x_min-1, x_max + 2, 1))

y_min = min(lst_y)
y_max = max(lst_y)

plt.yticks(range(y_min-1, y_max + 2, 1))

plt.show()

# %% [markdown]
# ### Legend

# %%
lst_y2 = [1, 4, 16]

# %%
# ლეგენდა
plt.plot(lst_x, lst_y, label='3x')
plt.plot(lst_x, lst_y2, label='x^2')

plt.xlabel('X Axis')
plt.ylabel('Y')

plt.legend()

plt.show()

# %% [markdown]
# ### Line Width

# %%
# წირის ზომის შეცვლა
plt.plot(lst_x, lst_y, label='3x', color='b', linewidth=5)
plt.plot(lst_x, lst_y2, label='x^2', color='k', linewidth=1)

plt.xlabel('X Axis')
plt.ylabel('Y')

# black - k
# blue - b

plt.legend()

plt.show()

# %% [markdown]
# ### Marker

# %%
# მარკერის ტიპის ცვლილება
plt.plot(lst_x, lst_y, label='3x', color='g', linewidth=1.5, marker='^')
plt.plot(lst_x, lst_y2, label='x^2', color='r', linewidth=1, marker='.', linestyle='--')

plt.xlabel('X Axis')
plt.ylabel('Y')


plt.legend()

plt.show()

# %%
# მარკერის ტიპის ცვლილება
lst_x1 = [1,4,16,7]
lst_y1 = [3,6,9,12]
plt.plot(lst_x1, lst_y1, label='3x', color='g', linewidth=1.5, marker='^')
plt.plot(lst_x, lst_y2, label='x^2', color='r', linewidth=1, marker='.', linestyle='--')

plt.xlabel('X Axis')
plt.ylabel('Y')


plt.legend()

plt.show()

# %%
# მარკერის ზომის ცვლილება
# მარკერის ტიპის ცვლილება
plt.plot(lst_x, lst_y, label='3x', color='g', linewidth=1.5, marker='^', markersize=8
)
plt.plot(lst_x, lst_y2, label='x^2', color='r', linewidth=1, marker='^', linestyle='--')

plt.xlabel('X Axis')
plt.ylabel('Y')

plt.legend()

plt.show()

# %%
x = np.arange(0, 5*np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y, color='green',marker='^')
plt.show()

# %% [markdown]
# ### fmt Formatting

# %%
# fmt formatting
# Color, Marker Type, Line Type
fmt = 'r*--'

plt.plot(lst_x, lst_y, label='3x', color='g', linewidth=1.5, marker='^', markersize =8
)
plt.plot(lst_x, lst_y2, fmt, label='x^2', linewidth=1,)

plt.xlabel('X Axis')
plt.ylabel('Y')


plt.legend()

plt.show()

# %% [markdown]
# ### Save Figure

# %%
# save figure
# fmt formatting
fmt = 'r*--'
plt.plot(lst_x, lst_y, label='3x', color='g', marker='^', markersize =8
)
plt.plot(lst_x, lst_y2, fmt, label='x^2', linewidth=1,)

plt.xlabel('X Axis')
plt.ylabel('Y')



plt.legend()

plt.savefig('intro_2_high.png', dpi=100) # Dots Per Inch. figsize * dpi. ex. 4 x 6 -- 1200 x 1800

plt.show()

# %% [markdown]
# ### fontdict

# %%
# fontdict
fmt = 'r*--'
plt.plot(lst_x, lst_y, label='3x', color='g', linewidth=1.5, marker='^', markersize =8
)
plt.plot(lst_x, lst_y2, fmt, label='x^2', linewidth=1,)

plt.xlabel('X Axis')
plt.ylabel('Y')

plt.legend()

plt.title('Our Functions',
          fontdict={'fontsize': 20,
                   'fontname': 'Comic Sans MS'})

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.

# %% [markdown]
# ### figsize

# %%
# figsize
plt.figure(figsize=(6, 3), dpi=100) # 6 X 4 Inches,

fmt = 'r*--'
plt.plot(lst_x, lst_y, label='3x', color='g', linewidth=1.5, marker='^', markersize =8
)
plt.plot(lst_x, lst_y2, fmt, label='x^2', linewidth=1,)

plt.xlabel('X Axis')
plt.ylabel('Y')

plt.legend()

plt.title('Our Functions',
          fontdict={'fontsize': 20,
                   'fontname': 'Comic Sans MS'})

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.

# %% [markdown]
# ## Bar Chart

# %%
bar_labels = ['A', 'B', 'C']
bar_values = [4, 9, 2]

# %%
# სვეტოვანი დიაგრამა
plt.bar(bar_labels, bar_values)

plt.title('sample bar plot')

plt.show()

# %% [markdown]
# ### .set_hatch()

# %%
# სვეტის შევსების ტიპის დაყენება
bars = plt.bar(bar_labels, bar_values)

bars[0].set_hatch('/')
bars[1].set_hatch('*')
bars[2].set_hatch('o')


plt.title('sample bar plot')

plt.show()

# %%
# სვეტის შევსების ტიპი
bar_labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
bar_values = [4, 9, 2, 0, -3, 7, 5]
bars = plt.bar(bar_labels, bar_values)

patterns = ['o', '*', '/']

for i, bar in enumerate(bars):
    bar.set_hatch(patterns[i % len(patterns)])

plt.title('sample bar plot')

plt.show()

# %% [markdown]
# ## Scatter

# %%
# plt.style.use('_mpl-gallery')

# მონაცემების შექმნა
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))
# size and color:
sizes = np.random.uniform(15, 80, len(x))

plt.scatter(x, y)

plt.show()

# %% [markdown]
# ## Animation

# %%
# !pip install foliantcontrib.imagemagick

# %%
# https://riptutorial.com/matplotlib/example/23562/save-animation-to-gif

import matplotlib.animation as animation
from matplotlib import rcParams

# make sure the full paths for ImageMagick and ffmpeg are configured
rcParams['animation.convert_path'] = r'C:\Program Files\ImageMagick\convert'
rcParams['animation.ffmpeg_path'] = r'C:\Program Files\ffmpeg\bin\ffmpeg.exe'

TWOPI = 2*np.pi

fig, ax = plt.subplots()

t = np.arange(0.0, TWOPI, 0.001)
s = np.sin(t)
l = plt.plot(t, s)

ax = plt.axis([0,TWOPI,-1,1])

redDot, = plt.plot([0], [np.sin(0)], 'ro')

def animate(i):
    redDot.set_data(i, np.sin(i))
    return redDot,

# create animation using the animate() function with no repeat
myAnimation = animation.FuncAnimation(fig, animate, frames=np.arange(0.0, TWOPI, 0.1), \
                                      interval=10, blit=True, repeat=False)

# save animation at 30 frames per second
myAnimation.save('myAnimation.gif', writer='imagemagick', fps=30)
# Out:
# <ipython-input-66-5d6508ca2ec7>:23: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   redDot.set_data(i, np.sin(i))
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.
# <ipython-input-66-5d6508ca2ec7>:23: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   redDot.set_data(i, np.sin(i))
