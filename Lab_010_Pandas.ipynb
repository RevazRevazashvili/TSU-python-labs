# %% [markdown]
# <a href="https://colab.research.google.com/github/RevazRevazashvili/TSU-python-labs/blob/main/Lab_010_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas Tutorial
# **pandas** არის სწრაფი, ძლიერი, მოქნილი და ადვილად გამოსაყენებელი ღია კოდის მონაცემთა ანალიზისა და მანიპულაციის ინსტრუმენტი, რომელიც აგებულია **python** პროგრამირების ენაზე.
#
# https://pandas.pydata.org/docs/index.html

# %% [markdown]
# ## ბიბლიოთეკის ჩატვირთვა

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## ძირითადი ობიექტი

# %% [markdown]
# ### Series
# ინდექსირებული ერთ განზომილებიანი სია

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(type(s))
s
# Out:
# <class 'pandas.core.series.Series'>
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"], name="calories")

print(myvar)
# Out:
# day1    420
# day2    380
# Name: calories, dtype: int64

# %%
s.size
# Out:
# 6

# %%
s.shape
# Out:
# (6,)

# %% [markdown]
# ### DataFrame
# ორგანზომილებიანი ცხრილური მონაცემები, ინდექსებით და სვეტის სახელებით

# %% [markdown]
# #### from Dictionary

# %%
names = ["Alex", "Bill", "Charles"]
ages = [15, 28, 36]
gender = ["Male", "Male", "Male"]

d = {"name": names, "age": ages, "gender": gender}

df = pd.DataFrame(d)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       name  age gender
# 0     Alex   15   Male
# 1     Bill   28   Male
# 2  Charles   36   Male

# %% [markdown]
# #### ცარიელი DataFrame-დან

# %%
df = pd.DataFrame()
df["name"] = names
df["age"] = ages
df["gender"] = gender
df
# Out:
#       name  age gender
# 0     Alex   15   Male
# 1     Bill   28   Male
# 2  Charles   36   Male

# %% [markdown]
# ## თვისებები

# %% [markdown]
# ### ატრიბუტები

# %% [markdown]
# #### size
# `.size`

# %%
df.size
# Out:
# 9

# %% [markdown]
# #### .columns
# `.columns`

# %%
df.columns
# Out:
# Index(['name', 'age', 'gender'], dtype='object')

# %%
cols = list(df.columns.values)
cols
# Out:
# ['name', 'age', 'gender']

# %%
cols = df.columns.values.tolist()
cols
# Out:
# ['name', 'age', 'gender']

# %% [markdown]
# #### .shape
# `.shape`

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# #### .index
# `.index`

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])
s.index

# %%
s

# %% [markdown]
# #### .info()
# `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   gender  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %% [markdown]
# ### მონაცემების მონახულება

# %% [markdown]
# #### .head() and .tail()
# `.head()` - first 5 rows
#
# `.tail()` - last 5 rows

# %%
df.head()
# Out:
#       name  age gender
# 0     Alex   15   Male
# 1     Bill   28   Male
# 2  Charles   36   Male

# %%
df.tail()
# Out:
#       name  age gender
# 0     Alex   15   Male
# 1     Bill   28   Male
# 2  Charles   36   Male

# %% [markdown]
# ### მონაცემების არჩევა

# %% [markdown]
# #### .loc - by label
# `.loc`

# %%
print(type(df['name']))
df['name']
# Out:
# <class 'pandas.core.series.Series'>
# 0       Alex
# 1       Bill
# 2    Charles
# Name: name, dtype: object

# %%
print(type(df[['name']]))
df[['name']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       name
# 0     Alex
# 1     Bill
# 2  Charles

# %%
# df['nam']

# %%
df.loc[:, 'name']
# Out:
# 0       Alex
# 1       Bill
# 2    Charles
# Name: name, dtype: object

# %%
df.loc[1, 'name']
# Out:
# 'Bill'

# %%
df.loc[:,:]
# Out:
#       name  age gender
# 0     Alex   15   Male
# 1     Bill   28   Male
# 2  Charles   36   Male

# %% [markdown]
# #### .iloc - პოზიციით
# `.iloc`

# %%
df.iloc[:, 0]
# Out:
# 0       Alex
# 1       Bill
# 2    Charles
# Name: name, dtype: object

# %%
df.iloc[:, 1]
# Out:
# 0    15
# 1    28
# 2    36
# Name: age, dtype: int64

# %%
df.iloc[:, :]
# Out:
#       name  age
# 0     Alex   15
# 1     Bill   28
# 2  Charles   36

# %% [markdown]
# #### .iterrows()
# `.iterrows()`

# %%
for index, row in df.iterrows():
    print(index)
    print(row)
# Out:
# 0
# name    Alex
# age       15
# Name: 0, dtype: object
# 1
# name    Bill
# age       28
# Name: 1, dtype: object
# 2
# name    Charles
# age          36
# Name: 2, dtype: object

# %% [markdown]
# #### .describe()
# `.describe()`

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   26.333333
# std    10.598742
# min    15.000000
# 25%    21.500000
# 50%    28.000000
# 75%    32.000000
# max    36.000000

# %% [markdown]
# ### Boolean Indexing

# %%
df['name']=='Alex'
# Out:
# 0     True
# 1    False
# 2    False
# Name: name, dtype: bool

# %%
df['age'] < 30
# Out:
# 0     True
# 1     True
# 2    False
# Name: age, dtype: bool

# %%
df[df['age']<30]
# Out:
#    name  age gender
# 0  Alex   15   Male
# 1  Bill   28   Male

# %%
s = pd.Series([True, False, True])
df[s]
# Out:
#       name  age gender
# 0     Alex   15   Male
# 2  Charles   36   Male

# %%
df[(df['name']=='Alex') | (df['age']<30)] # or |
# Out:
#    name  age gender
# 0  Alex   15   Male
# 1  Bill   28   Male

# %%
df.loc[(df['name']=='Alex') | (df['age']<30)]
# Out:
#    name  age
# 0  Alex   15
# 1  Bill   28

# %%
df.loc[(df['name']!='Alex')]
# Out:
#       name  age
# 1     Bill   28
# 2  Charles   36

# %%
df.loc[df['name']=='Alex', 'age']
# Out:
# 0    15
# Name: age, dtype: int64

# %%
new_df = df[(df['name'] != 'Alex')]
new_df
# Out:
#       name  age gender
# 1     Bill   28   Male
# 2  Charles   36   Male

# %%
new_df = new_df.reset_index()
new_df
# Out:
#    index     name  age
# 0      1     Bill   28
# 1      2  Charles   36

# %%
new_df = df[(df['name']!='Alex')]
new_df
# Out:
#       name  age
# 1     Bill   28
# 2  Charles   36

# %%
new_df = new_df.reset_index(drop=True)
new_df
# Out:
#       name  age
# 0     Bill   28
# 1  Charles   36

# %%
new_df = df[(df['name']!='Alex')]
new_df
# Out:
#       name  age
# 1     Bill   28
# 2  Charles   36

# %%
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#       name  age
# 0     Bill   28
# 1  Charles   36

# %% [markdown]
# ### Wrangling

# %% [markdown]
# #### calculations

# %%
df['new_age'] = df['age'] * 2.5
df
# Out:
#       name  age gender  new_age  Total
# 0     Alex   15   Male     37.5   90.0
# 1     Bill   28   Male     70.0  168.0
# 2  Charles   36   Male     90.0  216.0

# %%
df['Total'] = df['age'] + df['new_age']
df
# Out:
#       name  age gender  new_age  Total
# 0     Alex   15   Male     37.5   52.5
# 1     Bill   28   Male     70.0   98.0
# 2  Charles   36   Male     90.0  126.0

# %%
df.iloc[:,1:3]
# Out:
#    age gender
# 0   15   Male
# 1   28   Male
# 2   36   Male

# %%
df.iloc[:,3:5].sum(axis=1)
# Out:
# 0     90.0
# 1    168.0
# 2    216.0
# dtype: float64

# %%
# sum of columns from 1 to 3
df['New Total'] = df.iloc[:,3:5].sum(axis=1)
df
# Out:
#       name  age gender  new_age  Total  New Total
# 0     Alex   15   Male     37.5   52.5       90.0
# 1     Bill   28   Male     70.0   98.0      168.0
# 2  Charles   36   Male     90.0  126.0      216.0

# %%
# sum of column age
df['New Total1'] = df.loc[:,'age'].sum(axis=0)
df
# Out:
#       name  age gender  new_age  Total  New Total  New Total1
# 0     Alex   15   Male     37.5   52.5       90.0          79
# 1     Bill   28   Male     70.0   98.0      168.0          79
# 2  Charles   36   Male     90.0  126.0      216.0          79

# %%
df.loc[:, ['age', 'new_age']].sum(axis=1)
# Out:
# 0     52.5
# 1     98.0
# 2    126.0
# dtype: float64

# %%
lst_sum = df.loc[:, ['age', 'new_age']].sum(axis=1).to_list()
lst_sum
# Out:
# [52.5, 98.0, 126.0]

# %%
df.loc[:, ['age', 'new_age']].sum(axis=1).head(2)
# Out:
# 0    52.5
# 1    98.0
# dtype: float64

# %%
df['Total 2'] = df.loc[:, ['age', 'new_age']].mean(axis=1)
df
# Out:
#       name  age  new_age  Total  Total 2
# 0     Alex   15     37.5   52.5    26.25
# 1     Bill   28     70.0   98.0    49.00
# 2  Charles   36     90.0  126.0    63.00

# %% [markdown]
# #### changing index

# %%
df.set_index('name')
# Out:
#          age  new_age  Total  Total 2
# name
# Alex      15     37.5   52.5    26.25
# Bill      28     70.0   98.0    49.00
# Charles   36     90.0  126.0    63.00

# %% [markdown]
# #### String Methods
# See more at [Working with Text Data](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html)

# %%
df['name']
# Out:
# 0       Alex
# 1       Bill
# 2    Charles
# Name: name, dtype: object

# %%
df['name'].str.lower()
# Out:
# 0       alex
# 1       bill
# 2    charles
# Name: name, dtype: object

# %%
df['name'].str.contains('i')
# Out:
# 0    False
# 1     True
# 2    False
# Name: name, dtype: bool

# %%
df.loc[df['name'].str.contains('i')]
# Out:
#    name  age  new_age  Total  Total 2
# 1  Bill   28     70.0   98.0     49.0

# %%
df.loc[~df['name'].str.contains('i')]
# Out:
#       name  age  new_age  Total  Total 2
# 0     Alex   15     37.5   52.5    26.25
# 2  Charles   36     90.0  126.0    63.00

# %% [markdown]
# #### .drop()
# `.drop()`

# %%
df = df.drop(columns=['new_age', 'Total', 'Total 2'])

# %%
df
# Out:
#       name  age
# 0     Alex   15
# 1     Bill   28
# 2  Charles   36

# %%
df2 = pd.DataFrame({'name':['David'], 'age':[22]})
df2
# Out:
#     name  age
# 0  David   22

# %%
df = df.append(df2)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-b0991d620db9> in <cell line: 1>()
# ----> 1 df = df.append(df2)
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# #### .concat()
# `.concat()`

# %%
df = pd.DataFrame(d)
df
# Out:
#       name  age
# 0     Alex   15
# 1     Bill   28
# 2  Charles   36

# %%
df = pd.concat([df, df2])
df = df.reset_index(drop=True)
df
# Out:
#       name  age
# 0     Alex   15
# 1     Bill   28
# 2  Charles   36
# 3    David   22

# %%
df.loc[0, :]
# Out:
# name    Alex
# age       15
# Name: 0, dtype: object

# %%
df.iloc[3, :]
# Out:
# name    David
# age        22
# Name: 3, dtype: object

# %% [markdown]
# #### new column

# %%
df['interest'] = [np.nan] * df.shape[0]
df.head()
# Out:
#       name  age  interest
# 0     Alex   15       NaN
# 1     Bill   28       NaN
# 2  Charles   36       NaN
# 3    David   22       NaN

# %%
df['interest'] = np.nan
df.head()
# Out:
#       name  age  interest
# 0     Alex   15       NaN
# 1     Bill   28       NaN
# 2  Charles   36       NaN
# 3    David   22       NaN

# %% [markdown]
# #### .insert()
# `.insert()`

# %%
df.insert(1, 'country', np.nan)
df
# Out:
#       name  country  age  interest
# 0     Alex      NaN   15       NaN
# 1     Bill      NaN   28       NaN
# 2  Charles      NaN   36       NaN
# 3    David      NaN   22       NaN

# %% [markdown]
# #### .sort_values()
# `.sort_values()`

# %%
df.sort_values('age', ascending=False)
# Out:
#       name  country  age  interest
# 2  Charles      NaN   36       NaN
# 1     Bill      NaN   28       NaN
# 3    David      NaN   22       NaN
# 0     Alex      NaN   15       NaN

# %%
df.sort_values('age', ascending=False).reset_index(drop=True)
# Out:
#       name  country  age  interest
# 0  Charles      NaN   36       NaN
# 1     Bill      NaN   28       NaN
# 2    David      NaN   22       NaN
# 3     Alex      NaN   15       NaN

# %%
df
# Out:
#       name  country  age  interest
# 0     Alex      NaN   15       NaN
# 1     Bill      NaN   28       NaN
# 2  Charles      NaN   36       NaN
# 3    David      NaN   22       NaN

# %%
df['name_length'] = df['name'].str.len()
df
# Out:
#       name  country  age  interest  name_length
# 0     Alex      NaN   15       NaN            4
# 1     Bill      NaN   28       NaN            4
# 2  Charles      NaN   36       NaN            7
# 3    David      NaN   22       NaN            5

# %%
df.iloc[:,0].str.len() + df.iloc[:,2]
# Out:
# 0    19
# 1    32
# 2    43
# 3    27
# dtype: int64

# %%
df[['name_length', 'age']].sum(axis=1)
# Out:
# 0    19
# 1    32
# 2    43
# 3    27
# dtype: int64

# %%
df[['name_length', 'name', 'age', 'interest']]
# Out:
#    name_length     name  age  interest
# 0            4     Alex   15       NaN
# 1            4     Bill   28       NaN
# 2            7  Charles   36       NaN
# 3            5    David   22       NaN

# %% [markdown]
# ##### MLB

# %%
# !pip install openpyxl

# %%
df_mlb = pd.read_excel('mlb_players.xlsx')
print(df_mlb.columns)
df_mlb = df_mlb.drop(columns='Unnamed: 0')
df_mlb.head()
# Out:
# Index(['Unnamed: 0', 'Name', 'Team', 'Position', 'Height(inches)',
#        'Weight(pounds)', 'Age'],
#       dtype='object')
#               Name Team       Position  Height(inches)  Weight(pounds)    Age
# 0    Adam_Donachie  BAL        Catcher              74           180.0  22.99
# 1        Paul_Bako  BAL        Catcher              74           215.0  34.69
# 2  Ramon_Hernandez  BAL        Catcher              72           210.0  30.78
# 3     Kevin_Millar  BAL  First_Baseman              72           210.0  35.43
# 4      Chris_Gomez  BAL  First_Baseman              73           188.0  35.71

# %%
df_mlb = df_mlb.rename(columns={'Height(inches)': 'height',
                                'Weight(pounds)': 'weight'})
df_mlb.head()
# Out:
#               Name Team       Position  height  weight    Age
# 0    Adam_Donachie  BAL        Catcher      74   180.0  22.99
# 1        Paul_Bako  BAL        Catcher      74   215.0  34.69
# 2  Ramon_Hernandez  BAL        Catcher      72   210.0  30.78
# 3     Kevin_Millar  BAL  First_Baseman      72   210.0  35.43
# 4      Chris_Gomez  BAL  First_Baseman      73   188.0  35.71

# %%
df_mlb.columns
# Out:
# Index(['Name', 'Team', 'Position', 'height', 'weight', 'Age'], dtype='object')

# %%
df_mlb.columns = ['name', 'team', 'position', 'height', 'weight', 'age']

# %%
df_mlb.head()
# Out:
#               name team       position  height  weight    age
# 0    Adam_Donachie  BAL        Catcher      74   180.0  22.99
# 1        Paul_Bako  BAL        Catcher      74   215.0  34.69
# 2  Ramon_Hernandez  BAL        Catcher      72   210.0  30.78
# 3     Kevin_Millar  BAL  First_Baseman      72   210.0  35.43
# 4      Chris_Gomez  BAL  First_Baseman      73   188.0  35.71

# %%
df_mlb.sort_values('height', ascending=False)
# Out:
#                   name team          position  height  weight    age
# 928          Jon_Rauch  WAS    Relief_Pitcher      83   260.0  28.42
# 573      Randy_Johnson  ARZ  Starting_Pitcher      82   231.0  43.47
# 881        Chris_Young   SD  Starting_Pitcher      82   250.0  27.77
# 62        Andrew_Sisco  CWS    Relief_Pitcher      81   260.0  24.13
# 781   Mark_Hendrickson   LA  Starting_Pitcher      81   230.0  32.69
# ...                ...  ...               ...     ...     ...    ...
# 86       Chone_Figgins  ANA        Outfielder      68   160.0  29.10
# 972         Ray_Durham   SF    Second_Baseman      68   196.0  35.25
# 79      Maicer_Izturis  ANA     Third_Baseman      68   155.0  26.46
# 1008    David_Eckstein  STL         Shortstop      67   165.0  32.11
# 1007       Aaron_Miles  STL    Second_Baseman      67   180.0  30.21
#
# [1034 rows x 6 columns]

# %%
df_mlb.sort_values(by=['height', 'weight'])
# Out:
#                   name team          position  height  weight    age
# 1008    David_Eckstein  STL         Shortstop      67   165.0  32.11
# 1007       Aaron_Miles  STL    Second_Baseman      67   180.0  30.21
# 827       Fabio_Castro  PHI    Relief_Pitcher      68   150.0  22.11
# 79      Maicer_Izturis  ANA     Third_Baseman      68   155.0  26.46
# 86       Chone_Figgins  ANA        Outfielder      68   160.0  29.10
# ...                ...  ...               ...     ...     ...    ...
# 781   Mark_Hendrickson   LA  Starting_Pitcher      81   230.0  32.69
# 62        Andrew_Sisco  CWS    Relief_Pitcher      81   260.0  24.13
# 573      Randy_Johnson  ARZ  Starting_Pitcher      82   231.0  43.47
# 881        Chris_Young   SD  Starting_Pitcher      82   250.0  27.77
# 928          Jon_Rauch  WAS    Relief_Pitcher      83   260.0  28.42
#
# [1034 rows x 6 columns]

# %%
df_mlb.sort_values(by=['height', 'weight'], ascending=[False, True])
# Out:
#                   name team          position  height  weight    age
# 928          Jon_Rauch  WAS    Relief_Pitcher      83   260.0  28.42
# 573      Randy_Johnson  ARZ  Starting_Pitcher      82   231.0  43.47
# 881        Chris_Young   SD  Starting_Pitcher      82   250.0  27.77
# 781   Mark_Hendrickson   LA  Starting_Pitcher      81   230.0  32.69
# 62        Andrew_Sisco  CWS    Relief_Pitcher      81   260.0  24.13
# ...                ...  ...               ...     ...     ...    ...
# 867       Marcus_Giles   SD    Second_Baseman      68   180.0  28.79
# 972         Ray_Durham   SF    Second_Baseman      68   196.0  35.25
# 773       Delwyn_Young   LA        Outfielder      68   209.0  24.67
# 1008    David_Eckstein  STL         Shortstop      67   165.0  32.11
# 1007       Aaron_Miles  STL    Second_Baseman      67   180.0  30.21
#
# [1034 rows x 6 columns]

# %%
df_mlb.loc[df_mlb['team']=='LA']
# Out:
#                   name team          position  height  weight    age
# 760    Mike_Lieberthal   LA           Catcher      72   190.0  35.12
# 761     Russell_Martin   LA           Catcher      71   202.0  24.04
# 762       Olmedo_Saenz   LA     First_Baseman      71   221.0  36.39
# 763        James_Loney   LA     First_Baseman      75   200.0  22.81
# 764  Nomar_Garciaparra   LA     First_Baseman      72   190.0  33.60
# 765          Jeff_Kent   LA    Second_Baseman      73   210.0  38.98
# 766     Ramon_Martinez   LA    Second_Baseman      73   190.0  34.39
# 767    Marlon_Anderson   LA    Second_Baseman      71   200.0  33.15
# 768      Rafael_Furcal   LA         Shortstop      70   165.0  29.35
# 769     Wilson_Betemit   LA     Third_Baseman      75   190.0  26.59
# 770       Andy_LaRoche   LA     Third_Baseman      71   185.0  23.46
# 771          Matt_Kemp   LA        Outfielder      76   230.0  22.43
# 772       Andre_Ethier   LA        Outfielder      73   208.0  24.89
# 773       Delwyn_Young   LA        Outfielder      68   209.0  24.67
# 774        Jason_Repko   LA        Outfielder      71   175.0  26.17
# 775        Juan_Pierre   LA        Outfielder      72   180.0  29.54
# 776      Luis_Gonzalez   LA        Outfielder      74   200.0  39.49
# 777      Jason_Schmidt   LA  Starting_Pitcher      77   205.0  34.08
# 778         Randy_Wolf   LA  Starting_Pitcher      72   200.0  30.52
# 779         Brad_Penny   LA  Starting_Pitcher      76   250.0  28.77
# 780         Derek_Lowe   LA  Starting_Pitcher      78   210.0  33.75
# 781   Mark_Hendrickson   LA  Starting_Pitcher      81   230.0  32.69
# 782   Chad_Billingsley   LA  Starting_Pitcher      72   244.0  22.59
# 783      Takashi_Saito   LA    Relief_Pitcher      73   202.0  37.04
# 784   Jonathan_Broxton   LA    Relief_Pitcher      76   240.0  22.70
# 785      Hong-Chih_Kuo   LA    Relief_Pitcher      72   200.0  25.60
# 786        Eric_Stults   LA    Relief_Pitcher      72   215.0  27.23
# 787      Chin-Hui_Tsao   LA    Relief_Pitcher      74   177.0  25.74
# 788       Tim_Hamulack   LA    Relief_Pitcher      76   210.0  30.29
# 789    Yhency_Brazoban   LA    Relief_Pitcher      73   170.0  26.72
# 790        Brett_Tomko   LA    Relief_Pitcher      76   215.0  33.90
# 791         Joe_Beimel   LA    Relief_Pitcher      75   217.0  29.86
# 792      Elmer_Dessens   LA    Relief_Pitcher      70   198.0  36.13

# %%
df_mlb.loc[(df_mlb['team']=='LA') | (df_mlb['team']=='SF')]
# Out:
#                    name team        position  height  weight    age
# 760     Mike_Lieberthal   LA         Catcher      72   190.0  35.12
# 761      Russell_Martin   LA         Catcher      71   202.0  24.04
# 762        Olmedo_Saenz   LA   First_Baseman      71   221.0  36.39
# 763         James_Loney   LA   First_Baseman      75   200.0  22.81
# 764   Nomar_Garciaparra   LA   First_Baseman      72   190.0  33.60
# ...                 ...  ...             ...     ...     ...    ...
# 997        Brian_Wilson   SF  Relief_Pitcher      73   205.0  24.96
# 998       Merkin_Valdez   SF  Relief_Pitcher      77   208.0  25.30
# 999      Brad_Hennessey   SF  Relief_Pitcher      74   185.0  27.06
# 1000       Billy_Sadler   SF  Relief_Pitcher      72   190.0  25.44
# 1001          Pat_Misch   SF  Relief_Pitcher      74   170.0  25.53
#
# [67 rows x 6 columns]

# %%
team_filter = df_mlb['team'].isin(['LA', 'SF'])
print(team_filter)

df_mlb[team_filter]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1029    False
# 1030    False
# 1031    False
# 1032    False
# 1033    False
# Name: team, Length: 1034, dtype: bool
#                    name team        position  height  weight    age
# 760     Mike_Lieberthal   LA         Catcher      72   190.0  35.12
# 761      Russell_Martin   LA         Catcher      71   202.0  24.04
# 762        Olmedo_Saenz   LA   First_Baseman      71   221.0  36.39
# 763         James_Loney   LA   First_Baseman      75   200.0  22.81
# 764   Nomar_Garciaparra   LA   First_Baseman      72   190.0  33.60
# ...                 ...  ...             ...     ...     ...    ...
# 997        Brian_Wilson   SF  Relief_Pitcher      73   205.0  24.96
# 998       Merkin_Valdez   SF  Relief_Pitcher      77   208.0  25.30
# 999      Brad_Hennessey   SF  Relief_Pitcher      74   185.0  27.06
# 1000       Billy_Sadler   SF  Relief_Pitcher      72   190.0  25.44
# 1001          Pat_Misch   SF  Relief_Pitcher      74   170.0  25.53
#
# [67 rows x 6 columns]

# %%
team_filter = df_mlb['team'].isin(['LA', 'SF'])
position_filter = df_mlb['position'].isin(['Catcher', 'Relief_Pitcher'])
my_filter = (team_filter & position_filter)
# print(my_filter)
df_mlb[my_filter]
# Out:
#                   name team        position  height  weight    age
# 760    Mike_Lieberthal   LA         Catcher      72   190.0  35.12
# 761     Russell_Martin   LA         Catcher      71   202.0  24.04
# 783      Takashi_Saito   LA  Relief_Pitcher      73   202.0  37.04
# 784   Jonathan_Broxton   LA  Relief_Pitcher      76   240.0  22.70
# 785      Hong-Chih_Kuo   LA  Relief_Pitcher      72   200.0  25.60
# 786        Eric_Stults   LA  Relief_Pitcher      72   215.0  27.23
# 787      Chin-Hui_Tsao   LA  Relief_Pitcher      74   177.0  25.74
# 788       Tim_Hamulack   LA  Relief_Pitcher      76   210.0  30.29
# 789    Yhency_Brazoban   LA  Relief_Pitcher      73   170.0  26.72
# 790        Brett_Tomko   LA  Relief_Pitcher      76   215.0  33.90
# 791         Joe_Beimel   LA  Relief_Pitcher      75   217.0  29.86
# 792      Elmer_Dessens   LA  Relief_Pitcher      70   198.0  36.13
# 968      Bengie_Molina   SF         Catcher      71   220.0  32.61
# 969    Eliezer_Alfonzo   SF         Catcher      72   223.0  28.06
# 991       Vinnie_Chulk   SF  Relief_Pitcher      74   195.0  28.20
# 992      Kevin_Correia   SF  Relief_Pitcher      75   200.0  26.52
# 993        Steve_Kline   SF  Relief_Pitcher      73   215.0  34.52
# 994    Armando_Benitez   SF  Relief_Pitcher      76   229.0  34.32
# 995       Scott_Munter   SF  Relief_Pitcher      78   240.0  26.98
# 996      Jack_Taschner   SF  Relief_Pitcher      75   207.0  28.86
# 997       Brian_Wilson   SF  Relief_Pitcher      73   205.0  24.96
# 998      Merkin_Valdez   SF  Relief_Pitcher      77   208.0  25.30
# 999     Brad_Hennessey   SF  Relief_Pitcher      74   185.0  27.06
# 1000      Billy_Sadler   SF  Relief_Pitcher      72   190.0  25.44
# 1001         Pat_Misch   SF  Relief_Pitcher      74   170.0  25.53

# %% [markdown]
# ### Aggregation
# !needs more detailed examples

# %% [markdown]
# #### .groupby()
# `.groupby()`

# %%
df_mlb.groupby('team').sum()
# Out:
#                                                    name  \
# team
# ANA   Jose_MolinaJeff_MathisMike_NapoliCasey_Kotchma...
# ARZ   Chris_SnyderMiguel_MonteroConor_JacksonRobby_H...
# ATL   Brayan_Pe?aBrian_McCannCraig_WilsonChris_Woodw...
# BAL   Adam_DonachiePaul_BakoRamon_HernandezKevin_Mil...
# BOS   Doug_MirabelliJason_VaritekGeorge_KottarasKevi...
# CHC   Henry_BlancoMichael_BarrettGeovany_SotoScott_M...
# CIN   Javier_ValentinChad_MoellerDavid_RossJoey_Vott...
# CLE   Victor_MartinezKelly_ShoppachRyan_GarkoJoe_Ing...
# COL   Yorvit_TorrealbaChris_IannettaAlvin_ColinaTodd...
# CWS   A.J._PierzynskiToby_HallPaul_KonerkoTadahito_I...
# DET   Ivan_RodriguezVance_WilsonSean_CaseyChris_Shel...
# FLA   Miguel_OlivoMatt_TreanorMike_JacobsDan_UgglaRo...
# HOU   Brad_AusmusHumberto_QuinteroHector_GimenezLanc...
# KC    Jason_LaRueJohn_BuckRyan_ShealyRoss_GloadEsteb...
# LA    Mike_LieberthalRussell_MartinOlmedo_SaenzJames...
# MIN   Mike_RedmondJoe_MauerChris_HeintzJustin_Mornea...
# MLW   Damian_MillerJohnny_EstradaMike_RiveraJ.D._Clo...
# NYM   Paul_Lo_DucaRamon_CastroJulio_FrancoCarlos_Del...
# NYY   Jorge_PosadaWil_NievesAndy_PhillipsDoug_Mientk...
# OAK   Mike_PiazzaJason_KendallAdam_MelhuseNick_Swish...
# PHI   Ryan_BuddeRod_BarajasCarlos_RuizChris_CosteRya...
# PIT   Humberto_CotaRonny_PaulinoAdam_LaRocheRyan_Dou...
# SD    Josh_BardRob_BowenAdrian_GonzalezMarcus_GilesT...
# SEA   Rene_RiveraKenji_JohjimaRichie_SexsonBen_Brous...
# SF    Bengie_MolinaEliezer_AlfonzoLance_NiekroMark_S...
# STL   Gary_BennettYadier_MolinaJohn_NelsonAlbert_Puj...
# TB    Josh_PaulDioner_NavarroShawn_RiggansTy_Wiggint...
# TEX   Gerald_LairdMiguel_OjedaGuillermo_QuirozChris_...
# TOR   Gregg_ZaunJason_PhillipsLyle_OverbayRuss_Adams...
# WAS   Brian_SchneiderJesus_FloresLarry_BroadwayNick_...
#
#                                                position  height  weight  \
# team
# ANA   CatcherCatcherCatcherFirst_BasemanFirst_Basema...    2567  7038.0
# ARZ   CatcherCatcherFirst_BasemanFirst_BasemanFirst_...    2063  5826.0
# ATL   CatcherCatcherFirst_BasemanSecond_BasemanSecon...    2732  7382.0
# BAL   CatcherCatcherCatcherFirst_BasemanFirst_Basema...    2572  6872.0
# BOS   CatcherCatcherCatcherFirst_BasemanSecond_Basem...    2672  7374.0
# CHC   CatcherCatcherCatcherFirst_BasemanFirst_Basema...    2669  7349.0
# CIN   CatcherCatcherCatcherFirst_BasemanFirst_Basema...    2652  7138.0
# CLE   CatcherCatcherFirst_BasemanSecond_BasemanSecon...    2593  7058.0
# COL   CatcherCatcherCatcherFirst_BasemanSecond_Basem...    2588  6943.0
# CWS   CatcherCatcherFirst_BasemanSecond_BasemanShort...    2463  6947.0
# DET   CatcherCatcherFirst_BasemanFirst_BasemanSecond...    2727  7542.0
# FLA   CatcherCatcherFirst_BasemanSecond_BasemanShort...    2366  6476.0
# HOU   CatcherCatcherCatcherFirst_BasemanFirst_Basema...    2481  6734.0
# KC    CatcherCatcherFirst_BasemanFirst_BasemanSecond...    2573  6857.0
# LA    CatcherCatcherFirst_BasemanFirst_BasemanFirst_...    2421  6728.0
# MIN   CatcherCatcherCatcherFirst_BasemanSecond_Basem...    2412  6639.0
# MLW   CatcherCatcherCatcherCatcherFirst_BasemanSecon...    2576  7185.0
# NYM   CatcherCatcherFirst_BasemanFirst_BasemanSecond...    2772  7494.0
# NYY   CatcherCatcherFirst_BasemanFirst_BasemanFirst_...    2379  6666.0
# OAK   CatcherCatcherCatcherFirst_BasemanFirst_Basema...    2711  7362.0
# PHI   CatcherCatcherCatcherCatcherFirst_BasemanFirst...    2648  7027.0
# PIT   CatcherCatcherFirst_BasemanFirst_BasemanFirst_...    2576  7153.0
# SD    CatcherCatcherFirst_BasemanSecond_BasemanSecon...    2425  6724.0
# SEA   CatcherCatcherFirst_BasemanFirst_BasemanSecond...    2502  6755.0
# SF    CatcherCatcherFirst_BasemanFirst_BasemanSecond...    2501  6895.0
# STL   CatcherCatcherFirst_BasemanFirst_BasemanSecond...    2356  6452.0
# TB    CatcherCatcherCatcherFirst_BasemanSecond_Basem...    2432  6516.0
# TEX   CatcherCatcherCatcherCatcherFirst_BasemanSecon...    2593  7091.0
# TOR   CatcherCatcherFirst_BasemanSecond_BasemanSecon...    2512  6931.0
# WAS   CatcherCatcherFirst_BasemanFirst_BasemanSecond...    2669  7191.0
#
#           age
# team
# ANA   1008.31
# ARZ    779.38
# ATL   1048.05
# BAL   1017.18
# BOS   1072.22
# CHC   1023.09
# CIN   1074.71
# CLE    992.61
# COL    981.96
# CWS    932.94
# DET   1078.53
# FLA    826.12
# HOU   1016.99
# KC    1008.87
# LA     982.68
# MIN    931.98
# MLW   1016.42
# NYM   1159.95
# NYY    964.79
# OAK   1062.51
# PHI   1052.72
# PIT    951.82
# SD     980.53
# SEA    935.56
# SF    1017.61
# STL    975.28
# TB     884.31
# TEX    991.12
# TOR    975.70
# WAS    969.82

# %%
df_mlb[['height', 'weight', 'team']].groupby('team').mean()
# Out:
#          height      weight
# team
# ANA   73.342857  201.085714
# ARZ   73.678571  208.071429
# ATL   73.837838  199.513514
# BAL   73.485714  196.342857
# BOS   74.222222  204.833333
# CHC   74.138889  204.138889
# CIN   73.666667  203.942857
# CLE   74.085714  201.657143
# COL   73.942857  198.371429
# CWS   74.636364  210.515152
# DET   73.702703  203.837838
# FLA   73.937500  202.375000
# HOU   72.970588  198.058824
# KC    73.514286  195.914286
# LA    73.363636  203.878788
# MIN   73.090909  201.181818
# MLW   73.600000  205.285714
# NYM   72.947368  197.210526
# NYY   74.343750  208.312500
# OAK   73.270270  198.972973
# PHI   73.555556  195.194444
# PIT   73.600000  204.371429
# SD    73.484848  203.757576
# SEA   73.588235  198.676471
# SF    73.558824  202.794118
# STL   73.625000  201.625000
# TB    73.696970  197.454545
# TEX   74.085714  202.600000
# TOR   73.882353  203.852941
# WAS   74.138889  199.750000

# %%
df_mlb.groupby('team')[['height', 'weight']].mean()
# Out:
#          height      weight
# team
# ANA   73.342857  201.085714
# ARZ   73.678571  208.071429
# ATL   73.837838  199.513514
# BAL   73.485714  196.342857
# BOS   74.222222  204.833333
# CHC   74.138889  204.138889
# CIN   73.666667  203.942857
# CLE   74.085714  201.657143
# COL   73.942857  198.371429
# CWS   74.636364  210.515152
# DET   73.702703  203.837838
# FLA   73.937500  202.375000
# HOU   72.970588  198.058824
# KC    73.514286  195.914286
# LA    73.363636  203.878788
# MIN   73.090909  201.181818
# MLW   73.600000  205.285714
# NYM   72.947368  197.210526
# NYY   74.343750  208.312500
# OAK   73.270270  198.972973
# PHI   73.555556  195.194444
# PIT   73.600000  204.371429
# SD    73.484848  203.757576
# SEA   73.588235  198.676471
# SF    73.558824  202.794118
# STL   73.625000  201.625000
# TB    73.696970  197.454545
# TEX   74.085714  202.600000
# TOR   73.882353  203.852941
# WAS   74.138889  199.750000

# %%
df_mlb_grouped = df_mlb[['height', 'weight', 'team']].groupby('team')

# %%
df_mlb_grouped.mean()
# Out:
#          height      weight
# team
# ANA   73.342857  201.085714
# ARZ   73.678571  208.071429
# ATL   73.837838  199.513514
# BAL   73.485714  196.342857
# BOS   74.222222  204.833333
# CHC   74.138889  204.138889
# CIN   73.666667  203.942857
# CLE   74.085714  201.657143
# COL   73.942857  198.371429
# CWS   74.636364  210.515152
# DET   73.702703  203.837838
# FLA   73.937500  202.375000
# HOU   72.970588  198.058824
# KC    73.514286  195.914286
# LA    73.363636  203.878788
# MIN   73.090909  201.181818
# MLW   73.600000  205.285714
# NYM   72.947368  197.210526
# NYY   74.343750  208.312500
# OAK   73.270270  198.972973
# PHI   73.555556  195.194444
# PIT   73.600000  204.371429
# SD    73.484848  203.757576
# SEA   73.588235  198.676471
# SF    73.558824  202.794118
# STL   73.625000  201.625000
# TB    73.696970  197.454545
# TEX   74.085714  202.600000
# TOR   73.882353  203.852941
# WAS   74.138889  199.750000

# %%
df_mlb_grouped.sum()
# Out:
#       height  weight
# team
# ANA     2567  7038.0
# ARZ     2063  5826.0
# ATL     2732  7382.0
# BAL     2572  6872.0
# BOS     2672  7374.0
# CHC     2669  7349.0
# CIN     2652  7138.0
# CLE     2593  7058.0
# COL     2588  6943.0
# CWS     2463  6947.0
# DET     2727  7542.0
# FLA     2366  6476.0
# HOU     2481  6734.0
# KC      2573  6857.0
# LA      2421  6728.0
# MIN     2412  6639.0
# MLW     2576  7185.0
# NYM     2772  7494.0
# NYY     2379  6666.0
# OAK     2711  7362.0
# PHI     2648  7027.0
# PIT     2576  7153.0
# SD      2425  6724.0
# SEA     2502  6755.0
# SF      2501  6895.0
# STL     2356  6452.0
# TB      2432  6516.0
# TEX     2593  7091.0
# TOR     2512  6931.0
# WAS     2669  7191.0

# %% [markdown]
# #### to xlsx

# %%
# !pip install xlsxwriter

# %%
df_mlb.to_excel('test.xlsx')
